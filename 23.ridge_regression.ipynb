# %%
w_train = x.iloc[:,0:1].values
h_train = x.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 w_train = x.iloc[:,0:1].values
#       2 h_train = x.iloc[:,1].values
#
# NameError: name 'x' is not defined
