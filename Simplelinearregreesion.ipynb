# %%
from sklearn.metrics import r2_score
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
y=[1,2,3,4,5]
y1=[0.8,2.5,3.4,4.8,4.4]
R_square = r2_score(y,y1)
print('coefficient of Determination',R_square)
# Out:
# coefficient of Determination 0.8550000000000001

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
sns.scatterplot(data=df,x='area',y='price')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
df.area.values.reshape(-1,1)
# Out:
# array([[2600],
#        [3000],
#        [3200],
#        [3600],
#        [4000]])

# %%
reg = LinearRegression()
x = df.area.values.reshape(-1,1)
reg.fit(x,df.price) # fiting means training
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_  #this is slope
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
y = 135.78767123 * 3300 + 180616.43835616432
y
# Out:
# 628715.7534151643

# %%
y_original = df.price
y_predict = reg.predict(x)
R_square1 = r2_score(y_original,y_predict)
R_square1
# Out:
# 0.9584301138199486

# %%
sns.lmplot(data=df,x='area',y='price')
